# %% [markdown]
# Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in
# predicting the quality of wine.

# %%
#Answer :
import pandas as pd
df = pd.read_csv("winequalityN.csv")
l = list(df.columns)
print("The key features of the wine quality data set are : ", l)
# Out:
# The key features of the wine quality data set are :  ['type', 'fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

# %%
their importance in predicting the quality of red wine:
1. Fixed Acidity: Fixed acidity is the concentration of non-volatile acids in the wine. These acids play a role in determining the 
   overall tartness and acidity level of the wine. They contribute to the wine's structure and balance.
2. Volatile Acidity: Volatile acidity refers to the concentration of volatile acids in the wine. High levels of volatile acidity can
   lead to off-putting aromas and flavors, resembling vinegar. Controlling volatile acidity is crucial for maintaining the wine's 
   pleasantness.
3. Citric Acid: Citric acid is a weak organic acid found in wines. It can enhance the wine's freshness and contribute to its acidity.
   Proper levels of citric acid can add complexity to the wine's flavor profile.
4. Residual Sugar: Residual sugar is the amount of sugar left in the wine after fermentation. It impacts the wine's sweetness and 
   mouthfeel. The balance between residual sugar and acidity is essential for a harmonious taste.
5. Chlorides: Chloride levels affect the wine's saltiness and overall perception. Proper chloride concentration can enhance the wine's
   flavor and mouthfeel, but excessive amounts can lead to undesirable flavors.
6. Free Sulfur Dioxide: Free sulfur dioxide acts as an antioxidant and preservative in wine. It helps prevent spoilage and oxidation,
   which can negatively impact the wine's quality and stability.
7. Total Sulfur Dioxide: Total sulfur dioxide includes both free and bound forms of sulfur dioxide. It's an important measure of the
   wine's ability to resist spoilage and maintain its character over time.
8. Density: Density is a measure of the wine's mass per unit volume. It can provide insights into the wine's alcohol content and 
   overall body. Higher density wines are often more full-bodied.
9. pH: pH measures the acidity or alkalinity of the wine. It influences various chemical reactions that affect taste, color, and 
   stability. Proper pH levels contribute to a balanced and appealing wine.
10. Sulphates: Sulphates are a type of salt that can contribute to the wine's aroma, flavor, and stability. They are often added to
    wines as a preservative.
11. Alcohol: Alcohol content impacts the wine's body, mouthfeel, and overall perception. It can also influence the wine's perceived
    warmth and depth of flavor.
12. Quality (Target Variable): This is the feature you're trying to predict – the quality of the red wine. It's often rated by sensory
    experts based on taste, aroma, balance, and overall enjoyment.

# %% [markdown]
# Q2. How did you handle missing data in the wine quality data set during the feature engineering process?
# Discuss the advantages and disadvantages of different imputation techniques.

# %%
#Answer :
df1 = pd.read_csv("winequalityN.csv")
print(df1.shape)
df1.isna().sum()
# Out:
# (6497, 13)
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
In the given red wine quality data set there are : 10 missing values in acidity, 8 missing value in volatile acidity, 3 missing value
in citric acid, 2 missing value in residual sugar and chlorides, 9 missing value in pH, 4 missing value in sulphates. there are total 
38 missing values and data is large it contains around 6000 data and if we delet all these rows which contain the missing value
then it doesn't effect too much to the prediction model.
disadvantage : deleting the row is loss of data.

we can also replce the missing numerical feature with their means and in case of outliers we also replce it with the median and 
for the categorical feature we replace the missing value with the mode of the given column.
disadvantage : it decreases the performance of the machine learning model.

# %% [markdown]
# Q3. What are the key factors that affect students' performance in exams? How would you go about
# analyzing these factors using statistical techniques?

# %%
import pandas as pd
df = pd.read_csv("StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# Key factors that affect the student's performance in exams are : gender, race/ethnicity, parental level of education, lunch, test 
# preparation course
df['total_score'] = (df['math score'] + df['reading score'] + df['writing score'])

import matplotlib.pyplot as plt
import seaborn as sns

fig, axis = plt.subplots(1,3,figsize = (25,6))
plt.subplot(131)
sns.histplot(data = df, x = 'total_score', kde = True, hue = 'lunch')

plt.subplot(132)
sns.histplot(data = df, x = 'total_score', kde = True, hue = 'parental level of education')

plt.subplot(133)
sns.histplot(data = df, x = 'total_score', kde = True, hue = 'race/ethnicity')
# Out:
# <AxesSubplot: xlabel='total_score', ylabel='Count'>

# %%
we analyze student performace with help of visualization, here you clear see the student which eat stadard luch will perform better 
than wo eat free or reduced lunch. parental level of education doesn't effect he students performance. group A and group B student
perform poor and rest of the groups of students perform well in exams.

# %% [markdown]
# Q4. Describe the process of feature engineering in the context of the student performance data set. How
# did you select and transform the variables for your model?

# %%
Answer : Check Missing values : First we check for the missing value present in the data set if there is no missing value than it is 
         good but if there is missing value present than we delet the colum of missing values if the data is large number of obervation
         and there are only few missing values and in other cases we replace numerical missing values with their mean or median and 
         we replce categorical feature with their mode.
            
         Check dublicate : if the data set contain the duplicate then we delet the duplicate it doesn't effect the model performance.
        
         Check data type : some time numerical feature are present in string form or some other form but our model only understand the 
         numerical value then we convert all these value into numerical values if it is possible.

# %% [markdown]
# Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution
# of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to
# these features to improve normality?

# %%
#Answer :
import pandas as pd
df = pd.read_csv("winequalityN.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axis = plt.subplots(1,3,figsize = (25,6))
plt.subplot(131)
sns.histplot(data = df, x = 'fixed acidity', kde = True)

plt.subplot(132)
sns.histplot(data = df, x = 'volatile acidity', kde = True)

plt.subplot(133)
sns.histplot(data = df, x = 'citric acid', kde = True)
# Out:
# <AxesSubplot: xlabel='citric acid', ylabel='Count'>

# %%
fig, axis = plt.subplots(1,3,figsize = (25,6))
plt.subplot(131)
sns.histplot(data = df, x = 'residual sugar', kde = True)

plt.subplot(132)
sns.histplot(data = df, x = 'chlorides', kde = True)

plt.subplot(133)
sns.histplot(data = df, x = 'free sulfur dioxide', kde = True)
# Out:
# <AxesSubplot: xlabel='free sulfur dioxide', ylabel='Count'>

# %%
- distribution of fixed acidity is normal 
- distribution of chlorides is right skewed 
- distribution of free sulfur dioxide is right skewed
- distribution of residual sugar is right skewed
- distribution of citric acid is normal
- distribution of volatile acidity is right skewed

# %% [markdown]
# Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of
# features. What is the minimum number of principal components required to explain 90% of the variance in
# the data?

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Load the dataset
# Replace 'wine_data.csv' with the actual path to your dataset
data = pd.read_csv('winequalityN.csv')
data = data.dropna()
# Extract features (X) and labels (y) if applicable
X = data.drop(columns=['quality'])  # Adjust column name based on your dataset
y = data['quality']  # Adjust column name based on your dataset

# Encode categorical variables if present
X = pd.get_dummies(X)

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Perform PCA
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# Determine the number of principal components required to explain 90% variance
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance_ratio = np.cumsum(explained_variance_ratio)
num_components_90_percent = np.argmax(cumulative_variance_ratio >= 0.9) + 1

print(f"Number of components required to explain 90% variance: {num_components_90_percent}")
# Out:
# Number of components required to explain 90% variance: 8
